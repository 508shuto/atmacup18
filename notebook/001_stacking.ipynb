# %%
from pathlib import Path

import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import OrdinalEncoder

import lightgbm as lgb

# %%
exp_name = '001_stacking'

# %%
DATA_PATH = Path('/Users/gouyashuto/localrepository/atmacup18/input')
OUTPUT_DIR = Path('/Users/gouyashuto/localrepository/atmacup18/output')

# %%
train_df = pl.read_csv(DATA_PATH / 'train_features.csv')
test_df = pl.read_csv(DATA_PATH / 'test_features.csv')

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 30)
# (1727, 12)

# %%
CAT_COLS = ['gearShifter', 'scene']

TARGET_COLS = [
    'x_0', 'y_0', 'z_0',
    'x_1', 'y_1', 'z_1',
    'x_2', 'y_2', 'z_2',
    'x_3', 'y_3', 'z_3',
    'x_4', 'y_4', 'z_4',
    'x_5', 'y_5', 'z_5'
]

# %%
def get_agg_exprs(agg_cols) -> list[pl.Expr]:
    # 同一シーンから特徴量作成
    exprs = []
    exprs += [pl.col(agg_col).shift(-1).over("scene").alias(f"{agg_col}_shift-1") for agg_col in agg_cols] # 1ステップ前の時間の値
    exprs += [pl.col(agg_col).shift(1).over("scene").alias(f"{agg_col}_shift1") for agg_col in agg_cols] # 1ステップ後の時間の値
    exprs += [pl.col(agg_col).diff(-1).over("scene").alias(f"{agg_col}_diff-1") for agg_col in agg_cols] # 1ステップ前の時間の値との差分
    exprs += [pl.col(agg_col).diff(1).over("scene").alias(f"{agg_col}_diff1") for agg_col in agg_cols] # 1ステップ後の時間の値との差分
    exprs += [pl.col(agg_col).mean().over("scene").alias(f"{agg_col}_mean") for agg_col in agg_cols] # 同一シーンの平均値
    exprs += [pl.col(agg_col).std().over("scene").alias(f"{agg_col}_std") for agg_col in agg_cols] # 同一シーンの標準偏差
    exprs += [pl.col(agg_col).max().over("scene").alias(f"{agg_col}_max") for agg_col in agg_cols] # 同一シーンの最大値
    exprs += [pl.col(agg_col).min().over("scene").alias(f"{agg_col}_min") for agg_col in agg_cols] # 同一シーンの最小値
    return exprs

# %%
def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    agg_cols = ['vEgo', 'aEgo', 'steeringAngleDeg', 'steeringTorque', 'gas'] # 同一シーンから集計する値のカラム名
    df = (
        df
        .with_columns(
            scene = pl.col('ID').str.split('_').list[0],
            decisecond = pl.col('ID').str.split('_').list[1].cast(pl.Int32),
        )
        .sort(['scene', 'decisecond'])
        .with_columns(get_agg_exprs(agg_cols))
    )
    return df

# %%
def train(X: pd.DataFrame, y: pd.DataFrame, target: str):
    lgb_params = {
        'objective': 'regression',
        'metric': 'mae',
        'learning_rate': 0.01,
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'random_state': 42,
        'n_jobs': -1,
    }
    gkf = GroupKFold(n_splits=5)
    groups = X['scene']

    models = []
    oof = np.zeros(len(X))
    # for fold, (train_idx, valid_idx) in enumerate(gkf.split(X, y[target], groups=groups)):
    for fold in range(5):
        print('=' * 10, f'fold: {fold} start' + '=' * 10)
        train_X = X.loc[X.fold != fold].drop(columns=['scene', 'fold'] + [col for col in PREDICT_TARGET_COLS if not col.startswith(f"predict_{target.split('_')[0]}_")])
        train_y = y[target].loc[X.fold != fold]
        valid_X = X.loc[X.fold == fold].drop(columns=['scene', 'fold'] + [col for col in PREDICT_TARGET_COLS if not col.startswith(f"predict_{target.split('_')[0]}_")])
        valid_y = y[target].loc[X.fold == fold]

        train_data = lgb.Dataset(train_X, train_y)
        valid_data = lgb.Dataset(valid_X, valid_y, reference=train_data)

        model = lgb.train(
            lgb_params,
            train_data,
            valid_sets=[valid_data],
            num_boost_round=10000,
            callbacks=[lgb.early_stopping(100)],
        )
        oof[X.fold == fold] = model.predict(valid_X)
        models.append(model)
    return models, oof

def predict(X: pd.DataFrame, target: str, models: dict[str, list]):
    preds = []
    for model in models[target]:
        pred = model.predict(X.drop(columns=['scene'] + [col for col in PREDICT_TARGET_COLS if not col.startswith(f"predict_{target.split('_')[0]}_")]))
        preds.append(pred)
    return np.mean(preds, axis=0)

def evaluate(y_true: pd.DataFrame, y_pred: pd.DataFrame):
    return np.mean(np.abs(y_true - y_pred))

# %%
train_df = preprocess(train_df)

origin_test_ids = test_df['ID'].to_pandas()
test_df = preprocess(test_df)

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 72)
# (1727, 54)

# %%
train_df = train_df.to_pandas()
test_df = test_df.to_pandas()

# %%
# Sceneの名前を抜き出してDataFrameに加える
# train_df["scene"] = [i.split("_")[0] for i in train_df.ID]

# =======================================
# 5 Foldの作成
# =======================================

# train/val split
# SceneでFoldを分ける
scene_list = train_df.scene.unique()
fold_map = {}

for i, scene in enumerate(scene_list):
    fold_map[scene] = i % 5

train_df["fold"] = train_df.scene.map(fold_map)
train_df.head()
# Out:
#                                      ID       vEgo      aEgo  \
# 0  00066be8e20318869c38c66be466631a_320   5.701526  1.538456
# 1  00066be8e20318869c38c66be466631a_420  11.176292  0.279881
# 2  00066be8e20318869c38c66be466631a_520  10.472548  0.231099
# 3   000fb056f97572d384bae4f5fc1e0f28_20   3.316744  1.276733
# 4  000fb056f97572d384bae4f5fc1e0f28_120   6.055565 -0.117775
#
#    steeringAngleDeg  steeringTorque  brake  brakePressed    gas  gasPressed  \
# 0         -2.165777          -139.0    0.0         False  0.250        True
# 1        -11.625697           -44.0    0.0         False  0.000       False
# 2         -2.985105          -132.0    0.0         False  0.180        True
# 3        -31.725477          -114.0    0.0         False  0.255        True
# 4          7.632668           173.0    0.0         False  0.000       False
#
#   gearShifter  ...  aEgo_max  steeringAngleDeg_max  steeringTorque_max  \
# 0       drive  ...  1.538456             -2.165777               -44.0
# 1       drive  ...  1.538456             -2.165777               -44.0
# 2       drive  ...  1.538456             -2.165777               -44.0
# 3       drive  ...  1.276733              7.632668               173.0
# 4       drive  ...  1.276733              7.632668               173.0
#
#    gas_max  vEgo_min  aEgo_min  steeringAngleDeg_min  steeringTorque_min  \
# 0    0.250  5.701526  0.231099            -11.625697              -139.0
# 1    0.250  5.701526  0.231099            -11.625697              -139.0
# 2    0.250  5.701526  0.231099            -11.625697              -139.0
# 3    0.255  3.316744 -0.117775            -31.725477              -133.0
# 4    0.255  3.316744 -0.117775            -31.725477              -133.0
#
#    gas_min  fold
# 0      0.0     0
# 1      0.0     0
# 2      0.0     0
# 3      0.0     1
# 4      0.0     1
#
# [5 rows x 73 columns]

# %%
PREDICT_TARGET_COLS = []
for target in ['x', 'y', 'z']:
    for i in range(6):
        train_df[f"predict_{target}_{i}"] = 0
        test_df[f"predict_{target}_{i}"] = 0
        PREDICT_TARGET_COLS.append(f"predict_{target}_{i}")

oof_dir = Path('/Users/gouyashuto/localrepository/atmacup18/output/baseline52/oof')

for i in range(5):
    train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')

test_df[PREDICT_TARGET_COLS] = np.load(oof_dir.parent / 'test_preds.npy').mean(axis=0)

display(train_df.head())
display(test_df.head())
# Out:
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.73632812 4.984375   4.74609375 ... 4.92578125 4.6640625  4.0703125 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.01679993 -0.01702881 -0.02026367 ... -0.00261688  0.02404785
#   0.0491333 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.02738953 -0.00741577  0.00774002 ...  0.00051928  0.00629807
#  -0.00393677]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 6.078125 10.53125  10.109375 ... 10.265625  9.6875    8.578125]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.0567627  -0.00778198 -0.09954834 ...  0.00249481  0.09814453
#   0.16625977]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 6.07910156e-02 -2.43377686e-03  9.16290283e-03 ...  3.81469727e-05
#   9.50622559e-03  1.07955933e-02]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 9.671875  16.046875  15.5234375 ... 15.515625  14.5859375 13.1015625]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.12231445  0.02441406 -0.1965332  ... -0.02964783  0.20593262
#   0.34814453]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.11907959 -0.00152683  0.00666428 ... -0.0117569   0.01070404
#   0.00485229]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[13.4453125 21.59375   20.96875   ... 20.640625  19.328125  17.59375  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.18017578  0.06488037 -0.31274414 ... -0.05941772  0.34887695
#   0.56542969]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.1706543  -0.0291748   0.01397705 ... -0.01782227  0.01634216
#   0.0333252 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[17.4375   27.09375  26.421875 ... 25.6875   24.015625 22.125   ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.27416992  0.16040039 -0.47631836 ... -0.09075928  0.51074219
#   0.81396484]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.24755859 -0.03001404  0.04217529 ... -0.04193115  0.01133728
#   0.03320312]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[21.609375 32.5      31.921875 ... 30.671875 28.59375  26.640625]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.36669922  0.2208252  -0.64746094 ... -0.10467529  0.69140625
#   1.09179688]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_17279/3704653401.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.30957031 -0.06286621  0.04153442 ... -0.05184937  0.0093689
#   0.04031372]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, PREDICT_TARGET_COLS] = np.load(oof_dir / f'fold{i}_val_pred.npy')
#                                      ID       vEgo      aEgo  \
# 0  00066be8e20318869c38c66be466631a_320   5.701526  1.538456
# 1  00066be8e20318869c38c66be466631a_420  11.176292  0.279881
# 2  00066be8e20318869c38c66be466631a_520  10.472548  0.231099
# 3   000fb056f97572d384bae4f5fc1e0f28_20   3.316744  1.276733
# 4  000fb056f97572d384bae4f5fc1e0f28_120   6.055565 -0.117775
#
#    steeringAngleDeg  steeringTorque  brake  brakePressed    gas  gasPressed  \
# 0         -2.165777          -139.0    0.0         False  0.250        True
# 1        -11.625697           -44.0    0.0         False  0.000       False
# 2         -2.985105          -132.0    0.0         False  0.180        True
# 3        -31.725477          -114.0    0.0         False  0.255        True
# 4          7.632668           173.0    0.0         False  0.000       False
#
#   gearShifter  ...  predict_y_2  predict_y_3  predict_y_4  predict_y_5  \
# 0       drive  ...     0.119080    13.445312    -0.180176     0.170654
# 1       drive  ...    -0.001527    21.593750     0.064880    -0.029175
# 2       drive  ...     0.006664    20.968750    -0.312744     0.013977
# 3       drive  ...    -0.018555    11.250000     0.531250    -0.030075
# 4       drive  ...     0.030365     8.835938    -0.446533     0.038300
#
#    predict_z_0  predict_z_1  predict_z_2  predict_z_3  predict_z_4  \
# 0    17.437500    -0.274170     0.247559    21.609375    -0.366699
# 1    27.093750     0.160400    -0.030014    32.500000     0.220825
# 2    26.421875    -0.476318     0.042175    31.921875    -0.647461
# 3    13.992188     0.752930    -0.018341    16.765625     1.049805
# 4    11.609375    -0.596680     0.058685    14.554688    -0.725586
#
#    predict_z_5
# 0     0.309570
# 1    -0.062866
# 2     0.041534
# 3    -0.028473
# 4     0.096375
#
# [5 rows x 91 columns]
#                                      ID      vEgo      aEgo  steeringAngleDeg  \
# 0  012baccc145d400c896cb82065a93d42_120  3.374273 -0.019360        -34.008415
# 1  012baccc145d400c896cb82065a93d42_220  2.441048 -0.022754        307.860077
# 2  012baccc145d400c896cb82065a93d42_320  3.604152 -0.286239         10.774388
# 3  012baccc145d400c896cb82065a93d42_420  2.048902 -0.537628         61.045235
# 4  01d738e799d260a10f6324f78023b38f_120  2.201528 -1.898600          5.740093
#
#    steeringTorque  brake  brakePressed  gas  gasPressed gearShifter  ...  \
# 0            17.0    0.0         False  0.0       False       drive  ...
# 1           295.0    0.0          True  0.0       False       drive  ...
# 2          -110.0    0.0          True  0.0       False       drive  ...
# 3           189.0    0.0          True  0.0       False       drive  ...
# 4           -41.0    0.0          True  0.0       False       drive  ...
#
#    predict_y_2  predict_y_3 predict_y_4  predict_y_5  predict_z_0  \
# 0     0.004251     6.336719    0.040533     0.014632     7.878125
# 1     0.010564     3.069531    3.013672     0.023242     3.598438
# 2    -0.023334     6.393750   -0.097316    -0.038749     7.826562
# 3    -0.034274     3.173828    1.094751    -0.057326     3.703516
# 4    -0.046704     2.311719    0.016077    -0.064423     2.382812
#
#    predict_z_1  predict_z_2  predict_z_3  predict_z_4  predict_z_5
# 0     0.072980     0.019846     9.348437     0.122693     0.026746
# 1     4.293750     0.019300     4.112500     5.768750     0.038300
# 2    -0.164950    -0.051001     9.167188    -0.262469    -0.072753
# 3     1.642017    -0.087286     4.143359     2.276440    -0.123018
# 4     0.017225    -0.084155     2.349023     0.026129    -0.097980
#
# [5 rows x 72 columns]

# %%
remove_columns = ['ID']
X = train_df.drop(columns=remove_columns + TARGET_COLS)
y = train_df[TARGET_COLS]

test_X = test_df.drop(columns=remove_columns)

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X[CAT_COLS] = oe.fit_transform(X[CAT_COLS])
test_X[CAT_COLS] = oe.transform(test_X[CAT_COLS])

print(X.shape)
print(test_X.shape)
# Out:
# (43371, 72)
# (1727, 71)

# %%
# %%time

models_dict = {}
oof = pd.DataFrame(np.zeros_like(train_df.loc[:, TARGET_COLS]), columns=TARGET_COLS)

preds = test_df[['ID']]
preds[TARGET_COLS] = 0.0

for target in TARGET_COLS:
    print('=' * 10, f'target: {target} start' + '=' * 10)
    partial_model, partial_oofs = train(X, y, target)
    models_dict[target] = partial_model
    oof.loc[:, target] = partial_oofs
    preds.loc[:, target] = predict(test_X, target, models_dict)
# Out:
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ========== target: x_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [953]	valid_0's l1: 0.0613639
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1055]	valid_0's l1: 0.0620574
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [885]	valid_0's l1: 0.0610143
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [967]	valid_0's l1: 0.0633021
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [794]	valid_0's l1: 0.0626371
# ========== target: y_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [519]	valid_0's l1: 0.0314958
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [603]	valid_0's l1: 0.033364
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [738]	valid_0's l1: 0.0327048
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [508]	valid_0's l1: 0.0328278
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [537]	valid_0's l1: 0.0320241
# ========== target: z_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [255]	valid_0's l1: 0.0258601
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [197]	valid_0's l1: 0.0257118
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [340]	valid_0's l1: 0.0260504
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [247]	valid_0's l1: 0.0256794
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [160]	valid_0's l1: 0.0254527
# ========== target: x_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1377]	valid_0's l1: 0.130288
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1359]	valid_0's l1: 0.132663
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1191]	valid_0's l1: 0.130034
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1505]	valid_0's l1: 0.134869
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1134]	valid_0's l1: 0.133286
# ========== target: y_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2389]	valid_0's l1: 0.0708654
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3032]	valid_0's l1: 0.0736245
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1744]	valid_0's l1: 0.07362
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1954]	valid_0's l1: 0.0724562
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1715]	valid_0's l1: 0.0719225
# ========== target: z_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [484]	valid_0's l1: 0.0533674
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [293]	valid_0's l1: 0.0528563
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [381]	valid_0's l1: 0.0537566
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [671]	valid_0's l1: 0.0531049
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [174]	valid_0's l1: 0.0525199
# ========== target: x_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2097]	valid_0's l1: 0.222489
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1907]	valid_0's l1: 0.223358
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1374]	valid_0's l1: 0.222951
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1503]	valid_0's l1: 0.22946
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1777]	valid_0's l1: 0.226085
# ========== target: y_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3063]	valid_0's l1: 0.125205
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3088]	valid_0's l1: 0.127878
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2345]	valid_0's l1: 0.129944
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2122]	valid_0's l1: 0.127951
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4055]	valid_0's l1: 0.125885
# ========== target: z_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [435]	valid_0's l1: 0.08149
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [239]	valid_0's l1: 0.0804454
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [484]	valid_0's l1: 0.0816884
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [465]	valid_0's l1: 0.0815165
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [185]	valid_0's l1: 0.080118
# ========== target: x_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2824]	valid_0's l1: 0.344086
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2196]	valid_0's l1: 0.345872
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1967]	valid_0's l1: 0.350085
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2460]	valid_0's l1: 0.355492
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2041]	valid_0's l1: 0.350863
# ========== target: y_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3032]	valid_0's l1: 0.202447
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4753]	valid_0's l1: 0.205442
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3003]	valid_0's l1: 0.208172
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2627]	valid_0's l1: 0.205046
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3323]	valid_0's l1: 0.205826
# ========== target: z_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [444]	valid_0's l1: 0.110278
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's l1: 0.108994
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [547]	valid_0's l1: 0.110488
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [418]	valid_0's l1: 0.11045
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [191]	valid_0's l1: 0.108652
# ========== target: x_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2395]	valid_0's l1: 0.494566
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2895]	valid_0's l1: 0.497029
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2720]	valid_0's l1: 0.507047
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2843]	valid_0's l1: 0.51158
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2757]	valid_0's l1: 0.502441
# ========== target: y_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2865]	valid_0's l1: 0.307676
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3424]	valid_0's l1: 0.309767
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3835]	valid_0's l1: 0.314781
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2961]	valid_0's l1: 0.307881
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4935]	valid_0's l1: 0.311311
# ========== target: z_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [558]	valid_0's l1: 0.139444
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [326]	valid_0's l1: 0.138087
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [748]	valid_0's l1: 0.139872
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [388]	valid_0's l1: 0.140486
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [288]	valid_0's l1: 0.13849
# ========== target: x_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2613]	valid_0's l1: 0.663444
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3349]	valid_0's l1: 0.668274
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3236]	valid_0's l1: 0.684435
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3179]	valid_0's l1: 0.693684
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2935]	valid_0's l1: 0.678363
# ========== target: y_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3686]	valid_0's l1: 0.439579
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3422]	valid_0's l1: 0.441938
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4649]	valid_0's l1: 0.448786
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2879]	valid_0's l1: 0.441898
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4602]	valid_0's l1: 0.445704
# ========== target: z_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [697]	valid_0's l1: 0.169555
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [299]	valid_0's l1: 0.168184
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [580]	valid_0's l1: 0.17034
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [257]	valid_0's l1: 0.17188
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [313]	valid_0's l1: 0.168899
# CPU times: user 25min 33s, sys: 13min 3s, total: 38min 36s
# Wall time: 21min

# %%
for target in TARGET_COLS:
    print(f'{target} CV score: ', evaluate(y[target], oof[target]))
score = evaluate(y, oof)
print('Total CV score: ', score)
# Out:
# x_0 CV score:  0.062074554152148013
# y_0 CV score:  0.03248471437323804
# z_0 CV score:  0.02575107968912595
# x_1 CV score:  0.13222770293579364
# y_1 CV score:  0.07250091376744082
# z_1 CV score:  0.05312136022208847
# x_2 CV score:  0.22486849353513497
# y_2 CV score:  0.12737784175245384
# z_2 CV score:  0.08105166465372789
# x_3 CV score:  0.34928510624267084
# y_3 CV score:  0.20539287589766156
# z_3 CV score:  0.10977209776760731
# x_4 CV score:  0.5025442274530052
# y_4 CV score:  0.3102912403196514
# z_4 CV score:  0.13927600344347943
# x_5 CV score:  0.6776599466865915
# y_5 CV score:  0.4435910867405169
# z_5 CV score:  0.16977204743519841
# Total CV score:  0.20661349761486295

# %%
submission = pd.DataFrame(origin_test_ids).merge(preds, on='ID', how='left').drop(columns=['ID'])

output_path = OUTPUT_DIR / f'{exp_name}_{score:.4f}_submission.csv'
if output_path.exists():
    assert False, f'output file already exists. {output_path}'

submission.to_csv(output_path, index=False)
submission
# Out:
#            x_0       y_0       z_0        x_1       y_1       z_1        x_2  \
# 0     1.455784 -0.052414  0.002809   3.018601 -0.108654  0.007316   4.483010
# 1     0.934925  0.382405  0.001036   1.758698  1.036518  0.003828   2.402717
# 2     1.591639  0.009090 -0.000446   3.283091  0.010032 -0.003324   4.866868
# 3     0.820231  0.061564 -0.005490   1.641172  0.185296 -0.013182   2.424720
# 4     0.814276  0.003094 -0.003113   1.434161 -0.012013 -0.010169   1.858006
# ...        ...       ...       ...        ...       ...       ...        ...
# 1722  6.545769  0.022153  0.005623  13.816203  0.099906  0.007764  21.071531
# 1723  6.975885  0.004672 -0.006952  14.864170  0.003822 -0.046267  22.897432
# 1724  7.419897  0.001823  0.017816  15.679828 -0.008378  0.048305  23.904609
# 1725  6.530330  0.004168  0.012173  13.685084  0.007419  0.065197  20.781985
# 1726  5.810965 -0.248768  0.001856  12.302700 -1.139367  0.008283  18.848982
#
#            y_2       z_2        x_3       y_3       z_3        x_4       y_4  \
# 0    -0.141344  0.016730   5.885474 -0.155914  0.019541   7.367014 -0.113952
# 1     1.778358  0.009990   3.023882  2.484521  0.018533   3.803092  3.582791
# 2    -0.005291 -0.004523   6.288420 -0.011536 -0.009494   7.696518 -0.045258
# 3     0.389960 -0.027412   2.975819  0.781373 -0.042406   3.629555  1.337223
# 4    -0.026539 -0.019155   2.235629 -0.001633 -0.024143   2.154182  0.005558
# ...        ...       ...        ...       ...       ...        ...       ...
# 1722  0.255377 -0.002726  28.340876  0.479784 -0.015406  35.592144  0.787775
# 1723  0.001415 -0.104284  31.053862 -0.001159 -0.182103  39.254914  0.008279
# 1724 -0.020476  0.078439  32.050238 -0.062510  0.119835  40.112335 -0.111680
# 1725  0.035866  0.152102  27.839557  0.060909  0.285593  34.856052  0.097915
# 1726 -2.521849 -0.003828  25.415470 -4.375688 -0.032927  31.925231 -6.601664
#
#            z_4        x_5       y_5       z_5
# 0     0.006709   8.693657 -0.003260  0.012242
# 1     0.023413   4.413394  4.746160  0.027725
# 2    -0.019903   8.951873 -0.041451 -0.016332
# 3    -0.056979   4.451049  2.141549 -0.064447
# 4    -0.042546   1.658647  0.003734 -0.053759
# ...        ...        ...       ...       ...
# 1722 -0.037673  43.125573  1.143024 -0.063932
# 1723 -0.292423  47.534522  0.033680 -0.428858
# 1724  0.171338  48.055613 -0.153721  0.213097
# 1725  0.458288  41.893147  0.188924  0.645322
# 1726 -0.083162  38.362352 -9.081833 -0.163992
#
# [1727 rows x 18 columns]
