# %%
from pathlib import Path

import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import OrdinalEncoder

import lightgbm as lgb

# %%
exp_name = '002_stacking'

# %%
DATA_PATH = Path('/Users/gouyashuto/localrepository/atmacup18/input')
OUTPUT_DIR = Path('/Users/gouyashuto/localrepository/atmacup18/output')

# %%
train_df = pl.read_csv(DATA_PATH / 'train_features.csv')
test_df = pl.read_csv(DATA_PATH / 'test_features.csv')

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 30)
# (1727, 12)

# %%
CAT_COLS = ['gearShifter', 'scene']

TARGET_COLS = [
    'x_0', 'y_0', 'z_0',
    'x_1', 'y_1', 'z_1',
    'x_2', 'y_2', 'z_2',
    'x_3', 'y_3', 'z_3',
    'x_4', 'y_4', 'z_4',
    'x_5', 'y_5', 'z_5'
]

# %%
def get_agg_exprs(agg_cols) -> list[pl.Expr]:
    # 同一シーンから特徴量作成
    exprs = []
    exprs += [pl.col(agg_col).shift(-1).over("scene").alias(f"{agg_col}_shift-1") for agg_col in agg_cols] # 1ステップ前の時間の値
    exprs += [pl.col(agg_col).shift(1).over("scene").alias(f"{agg_col}_shift1") for agg_col in agg_cols] # 1ステップ後の時間の値
    exprs += [pl.col(agg_col).diff(-1).over("scene").alias(f"{agg_col}_diff-1") for agg_col in agg_cols] # 1ステップ前の時間の値との差分
    exprs += [pl.col(agg_col).diff(1).over("scene").alias(f"{agg_col}_diff1") for agg_col in agg_cols] # 1ステップ後の時間の値との差分
    exprs += [pl.col(agg_col).mean().over("scene").alias(f"{agg_col}_mean") for agg_col in agg_cols] # 同一シーンの平均値
    exprs += [pl.col(agg_col).std().over("scene").alias(f"{agg_col}_std") for agg_col in agg_cols] # 同一シーンの標準偏差
    exprs += [pl.col(agg_col).max().over("scene").alias(f"{agg_col}_max") for agg_col in agg_cols] # 同一シーンの最大値
    exprs += [pl.col(agg_col).min().over("scene").alias(f"{agg_col}_min") for agg_col in agg_cols] # 同一シーンの最小値
    return exprs

# %%
def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    agg_cols = ['vEgo', 'aEgo', 'steeringAngleDeg', 'steeringTorque', 'gas'] # 同一シーンから集計する値のカラム名
    df = (
        df
        .with_columns(
            scene = pl.col('ID').str.split('_').list[0],
            decisecond = pl.col('ID').str.split('_').list[1].cast(pl.Int32),
        )
        .sort(['scene', 'decisecond'])
        .with_columns(get_agg_exprs(agg_cols))
    )
    return df

# %%
def train(X: pd.DataFrame, y: pd.DataFrame, target: str):
    lgb_params = {
        'objective': 'regression',
        'metric': 'mae',
        'learning_rate': 0.01,
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'random_state': 42,
        'n_jobs': -1,
    }
    gkf = GroupKFold(n_splits=5)
    groups = X['scene']

    models = []
    oof = np.zeros(len(X))
    # for fold, (train_idx, valid_idx) in enumerate(gkf.split(X, y[target], groups=groups)):
    for fold in range(5):
        print('=' * 10, f'fold: {fold} start' + '=' * 10)
        train_X = X.loc[X.fold != fold].drop(columns=['scene', 'fold'])
        train_y = y[target].loc[X.fold != fold]
        valid_X = X.loc[X.fold == fold].drop(columns=['scene', 'fold'])
        valid_y = y[target].loc[X.fold == fold]

        train_data = lgb.Dataset(train_X, train_y)
        valid_data = lgb.Dataset(valid_X, valid_y, reference=train_data)

        model = lgb.train(
            lgb_params,
            train_data,
            valid_sets=[valid_data],
            num_boost_round=10000,
            callbacks=[lgb.early_stopping(100)],
        )
        oof[X.fold == fold] = model.predict(valid_X)
        models.append(model)
    return models, oof

def predict(X: pd.DataFrame, models: list):
    preds = []
    for model in models:
        pred = model.predict(X.drop(columns=['scene']))
        preds.append(pred)
    return np.mean(preds, axis=0)

def evaluate(y_true: pd.DataFrame, y_pred: pd.DataFrame):
    return np.mean(np.abs(y_true - y_pred))

# %%
train_df = preprocess(train_df)

origin_test_ids = test_df['ID'].to_pandas()
test_df = preprocess(test_df)

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 72)
# (1727, 54)

# %%
train_df = train_df.to_pandas()
test_df = test_df.to_pandas()

# %%
# Sceneの名前を抜き出してDataFrameに加える
# train_df["scene"] = [i.split("_")[0] for i in train_df.ID]

# =======================================
# 5 Foldの作成
# =======================================

# train/val split
# SceneでFoldを分ける
scene_list = train_df.scene.unique()
fold_map = {}

for i, scene in enumerate(scene_list):
    fold_map[scene] = i % 5

train_df["fold"] = train_df.scene.map(fold_map)
train_df.head()
# Out:
#                                      ID       vEgo      aEgo  \
# 0  00066be8e20318869c38c66be466631a_320   5.701526  1.538456
# 1  00066be8e20318869c38c66be466631a_420  11.176292  0.279881
# 2  00066be8e20318869c38c66be466631a_520  10.472548  0.231099
# 3   000fb056f97572d384bae4f5fc1e0f28_20   3.316744  1.276733
# 4  000fb056f97572d384bae4f5fc1e0f28_120   6.055565 -0.117775
#
#    steeringAngleDeg  steeringTorque  brake  brakePressed    gas  gasPressed  \
# 0         -2.165777          -139.0    0.0         False  0.250        True
# 1        -11.625697           -44.0    0.0         False  0.000       False
# 2         -2.985105          -132.0    0.0         False  0.180        True
# 3        -31.725477          -114.0    0.0         False  0.255        True
# 4          7.632668           173.0    0.0         False  0.000       False
#
#   gearShifter  ...  aEgo_max  steeringAngleDeg_max  steeringTorque_max  \
# 0       drive  ...  1.538456             -2.165777               -44.0
# 1       drive  ...  1.538456             -2.165777               -44.0
# 2       drive  ...  1.538456             -2.165777               -44.0
# 3       drive  ...  1.276733              7.632668               173.0
# 4       drive  ...  1.276733              7.632668               173.0
#
#    gas_max  vEgo_min  aEgo_min  steeringAngleDeg_min  steeringTorque_min  \
# 0    0.250  5.701526  0.231099            -11.625697              -139.0
# 1    0.250  5.701526  0.231099            -11.625697              -139.0
# 2    0.250  5.701526  0.231099            -11.625697              -139.0
# 3    0.255  3.316744 -0.117775            -31.725477              -133.0
# 4    0.255  3.316744 -0.117775            -31.725477              -133.0
#
#    gas_min  fold
# 0      0.0     0
# 1      0.0     0
# 2      0.0     0
# 3      0.0     1
# 4      0.0     1
#
# [5 rows x 73 columns]

# %%
predict_target_cols = []
for target in ['x', 'y', 'z']:
    for i in range(6):
        train_df[f"predict_{target}_{i}"] = 0
        test_df[f"predict_{target}_{i}"] = 0
        predict_target_cols.append(f"predict_{target}_{i}")

oof_dir = Path('/Users/gouyashuto/localrepository/atmacup18/output/baseline54/oof')

for i in range(5):
    train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')

test_df[predict_target_cols] = np.load(oof_dir.parent / 'test_preds.npy').mean(axis=0)

display(train_df.head())
display(test_df.head())
# Out:
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.71679688 4.9453125  4.7578125  ... 4.95703125 4.6640625  4.0703125 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.00503159  0.00510788 -0.01817322 ...  0.00699234  0.0322876
#   0.06469727]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.01626587 -0.00072193  0.00748062 ...  0.00138569  0.002388
#   0.00262451]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 6.03515625 10.4453125  10.1328125  ... 10.3671875   9.7421875
#   8.5859375 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.01168823 -0.01069641 -0.07678223 ...  0.00722122  0.15307617
#   0.24536133]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.04019165 -0.00722122  0.0168457  ...  0.01041412  0.01332092
#   0.01068878]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 9.625     15.9375    15.5546875 ... 15.703125  14.6875    13.1015625]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.04333496 -0.03884888 -0.19152832 ...  0.01377869  0.35791016
#   0.53955078]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.06860352 -0.03231812  0.02999878 ...  0.02423096  0.03381348
#   0.04055786]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[13.40625  21.359375 21.       ... 20.953125 19.5625   17.625   ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.10668945 -0.05560303 -0.31640625 ...  0.0241394   0.65527344
#   0.92333984]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.10083008 -0.03015137  0.04351807 ...  0.02661133  0.01342773
#   0.03738403]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[17.359375 26.75     26.359375 ... 26.171875 24.359375 22.171875]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.14892578 -0.09295654 -0.46142578 ...  0.04019165  1.
#   1.39550781]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.14379883 -0.04415894  0.05114746 ...  0.02856445  0.03375244
#   0.04434204]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[21.453125 32.03125  31.796875 ... 31.359375 29.171875 26.78125 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[-0.2109375  -0.11907959 -0.66699219 ...  0.05725098  1.38378906
#   1.89453125]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
# /var/folders/vq/4c8kgm65475ctdqgk6_bw_zw0000gn/T/ipykernel_86289/532204916.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 0.1965332  -0.04269409  0.07183838 ...  0.05105591  0.04144287
#   0.06170654]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[train_df.fold == i, predict_target_cols] = np.load(oof_dir / f'fold{i}_val_pred.npy')
#                                      ID       vEgo      aEgo  \
# 0  00066be8e20318869c38c66be466631a_320   5.701526  1.538456
# 1  00066be8e20318869c38c66be466631a_420  11.176292  0.279881
# 2  00066be8e20318869c38c66be466631a_520  10.472548  0.231099
# 3   000fb056f97572d384bae4f5fc1e0f28_20   3.316744  1.276733
# 4  000fb056f97572d384bae4f5fc1e0f28_120   6.055565 -0.117775
#
#    steeringAngleDeg  steeringTorque  brake  brakePressed    gas  gasPressed  \
# 0         -2.165777          -139.0    0.0         False  0.250        True
# 1        -11.625697           -44.0    0.0         False  0.000       False
# 2         -2.985105          -132.0    0.0         False  0.180        True
# 3        -31.725477          -114.0    0.0         False  0.255        True
# 4          7.632668           173.0    0.0         False  0.000       False
#
#   gearShifter  ...  predict_y_2  predict_y_3  predict_y_4  predict_y_5  \
# 0       drive  ...     0.068604    13.406250    -0.106689     0.100830
# 1       drive  ...    -0.032318    21.359375    -0.055603    -0.030151
# 2       drive  ...     0.029999    21.000000    -0.316406     0.043518
# 3       drive  ...    -0.001828    11.468750     0.490967    -0.003960
# 4       drive  ...     0.047394     8.835938    -0.600586     0.087708
#
#    predict_z_0  predict_z_1  predict_z_2  predict_z_3  predict_z_4  \
# 0    17.359375    -0.148926     0.143799    21.453125    -0.210938
# 1    26.750000    -0.092957    -0.044159    32.031250    -0.119080
# 2    26.359375    -0.461426     0.051147    31.796875    -0.666992
# 3    14.250000     0.701660    -0.001144    17.062500     0.941406
# 4    11.687500    -0.837891     0.123413    14.718750    -1.080078
#
#    predict_z_5
# 0     0.196533
# 1    -0.042694
# 2     0.071838
# 3    -0.007965
# 4     0.146484
#
# [5 rows x 91 columns]
#                                      ID      vEgo      aEgo  steeringAngleDeg  \
# 0  012baccc145d400c896cb82065a93d42_120  3.374273 -0.019360        -34.008415
# 1  012baccc145d400c896cb82065a93d42_220  2.441048 -0.022754        307.860077
# 2  012baccc145d400c896cb82065a93d42_320  3.604152 -0.286239         10.774388
# 3  012baccc145d400c896cb82065a93d42_420  2.048902 -0.537628         61.045235
# 4  01d738e799d260a10f6324f78023b38f_120  2.201528 -1.898600          5.740093
#
#    steeringTorque  brake  brakePressed  gas  gasPressed gearShifter  ...  \
# 0            17.0    0.0         False  0.0       False       drive  ...
# 1           295.0    0.0          True  0.0       False       drive  ...
# 2          -110.0    0.0          True  0.0       False       drive  ...
# 3           189.0    0.0          True  0.0       False       drive  ...
# 4           -41.0    0.0          True  0.0       False       drive  ...
#
#    predict_y_2  predict_y_3 predict_y_4  predict_y_5  predict_z_0  \
# 0    -0.000943     6.353906   -0.014349     0.003911     7.903906
# 1    -0.008749     3.152344    2.930469    -0.010068     3.711328
# 2    -0.012073     6.279687   -0.085297    -0.018196     7.651562
# 3     0.002670     3.082422    0.855371    -0.010119     3.558203
# 4    -0.035065     2.250000    0.018497    -0.052002     2.322266
#
#    predict_z_1  predict_z_2  predict_z_3  predict_z_4  predict_z_5
# 0    -0.018317    -0.004318     9.403125     0.010196    -0.011084
# 1     4.241016    -0.004283     4.189844     5.668750    -0.003876
# 2    -0.157382    -0.032669     8.921875    -0.220819    -0.049052
# 3     1.234082    -0.017709     3.958203     1.660352    -0.017847
# 4     0.019189    -0.074371     2.237109     0.025281    -0.075854
#
# [5 rows x 72 columns]

# %%
remove_columns = ['ID']
X = train_df.drop(columns=remove_columns + TARGET_COLS)
y = train_df[TARGET_COLS]

test_X = test_df.drop(columns=remove_columns)

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X[CAT_COLS] = oe.fit_transform(X[CAT_COLS])
test_X[CAT_COLS] = oe.transform(test_X[CAT_COLS])

print(X.shape)
print(test_X.shape)
# Out:
# (43371, 72)
# (1727, 71)

# %%
# %%time

models_dict = {}
oof = pd.DataFrame(np.zeros_like(train_df.loc[:, TARGET_COLS]), columns=TARGET_COLS)

preds = test_df[['ID']]
preds[TARGET_COLS] = 0.0

for target in TARGET_COLS:
    print('=' * 10, f'target: {target} start' + '=' * 10)
    partial_model, partial_oofs = train(X, y, target)
    models_dict[target] = partial_model
    oof.loc[:, target] = partial_oofs
    preds.loc[:, target] = predict(test_X, models_dict[target])
# Out:
# ========== target: x_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Early stopping, best iteration is:
# [1252]	valid_0's l1: 0.0614224
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1000]	valid_0's l1: 0.0621864
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1007]	valid_0's l1: 0.0609351
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [895]	valid_0's l1: 0.0634526
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [820]	valid_0's l1: 0.0628582
# ========== target: y_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [494]	valid_0's l1: 0.0316008
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [474]	valid_0's l1: 0.0333271
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [445]	valid_0's l1: 0.03266
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [882]	valid_0's l1: 0.0326329
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [555]	valid_0's l1: 0.0320653
# ========== target: z_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [298]	valid_0's l1: 0.0258242
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [178]	valid_0's l1: 0.0256664
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l1: 0.0260958
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [311]	valid_0's l1: 0.0257869
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l1: 0.0254277
# ========== target: x_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1469]	valid_0's l1: 0.130691
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1856]	valid_0's l1: 0.132336
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1890]	valid_0's l1: 0.130153
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1558]	valid_0's l1: 0.135569
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1194]	valid_0's l1: 0.13351
# ========== target: y_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1679]	valid_0's l1: 0.0711075
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2959]	valid_0's l1: 0.0734188
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1562]	valid_0's l1: 0.0736577
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1822]	valid_0's l1: 0.072582
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2558]	valid_0's l1: 0.0722281
# ========== target: z_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [275]	valid_0's l1: 0.053172
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's l1: 0.0531356
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [401]	valid_0's l1: 0.0538847
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [490]	valid_0's l1: 0.0534904
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [218]	valid_0's l1: 0.0525158
# ========== target: x_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3024]	valid_0's l1: 0.222045
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1880]	valid_0's l1: 0.223971
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1393]	valid_0's l1: 0.223965
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2340]	valid_0's l1: 0.228836
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1999]	valid_0's l1: 0.226286
# ========== target: y_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2960]	valid_0's l1: 0.125217
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3614]	valid_0's l1: 0.126961
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4118]	valid_0's l1: 0.129105
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2995]	valid_0's l1: 0.12804
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2674]	valid_0's l1: 0.127537
# ========== target: z_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [340]	valid_0's l1: 0.0813918
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's l1: 0.0806352
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [501]	valid_0's l1: 0.0822382
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [286]	valid_0's l1: 0.0821961
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [324]	valid_0's l1: 0.0801489
# ========== target: x_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2401]	valid_0's l1: 0.343722
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2900]	valid_0's l1: 0.345199
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3056]	valid_0's l1: 0.348526
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2842]	valid_0's l1: 0.355952
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2796]	valid_0's l1: 0.34976
# ========== target: y_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4643]	valid_0's l1: 0.200398
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4655]	valid_0's l1: 0.202179
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4254]	valid_0's l1: 0.208295
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2934]	valid_0's l1: 0.205463
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3606]	valid_0's l1: 0.20687
# ========== target: z_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [411]	valid_0's l1: 0.110256
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [275]	valid_0's l1: 0.109261
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [491]	valid_0's l1: 0.111327
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [496]	valid_0's l1: 0.111018
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [426]	valid_0's l1: 0.108788
# ========== target: x_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3836]	valid_0's l1: 0.490125
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3603]	valid_0's l1: 0.497122
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3626]	valid_0's l1: 0.504426
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3256]	valid_0's l1: 0.511671
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2905]	valid_0's l1: 0.502439
# ========== target: y_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2694]	valid_0's l1: 0.302544
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4416]	valid_0's l1: 0.304083
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4697]	valid_0's l1: 0.313195
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3445]	valid_0's l1: 0.307875
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4486]	valid_0's l1: 0.313957
# ========== target: z_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [505]	valid_0's l1: 0.139192
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [334]	valid_0's l1: 0.138293
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [591]	valid_0's l1: 0.140838
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [510]	valid_0's l1: 0.140739
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [385]	valid_0's l1: 0.138617
# ========== target: x_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3767]	valid_0's l1: 0.661642
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2893]	valid_0's l1: 0.672564
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3819]	valid_0's l1: 0.68437
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3424]	valid_0's l1: 0.695054
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3316]	valid_0's l1: 0.676187
# ========== target: y_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3284]	valid_0's l1: 0.430225
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3537]	valid_0's l1: 0.433767
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4140]	valid_0's l1: 0.446792
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3443]	valid_0's l1: 0.439498
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3483]	valid_0's l1: 0.450604
# ========== target: z_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l1: 0.168853
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [385]	valid_0's l1: 0.168571
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [611]	valid_0's l1: 0.171627
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [407]	valid_0's l1: 0.172157
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	valid_0's l1: 0.169549
# CPU times: user 29min 30s, sys: 8min 36s, total: 38min 7s
# Wall time: 18min 57s

# %%
for target in TARGET_COLS:
    print(f'{target} CV score: ', evaluate(y[target], oof[target]))
score = evaluate(y, oof)
print('Total CV score: ', score)
# Out:
# x_0 CV score:  0.06217037856447635
# y_0 CV score:  0.0324585178364432
# z_0 CV score:  0.025760442318709362
# x_1 CV score:  0.13245106719065416
# y_1 CV score:  0.07260173964934723
# z_1 CV score:  0.05324038719709783
# x_2 CV score:  0.22502233678350134
# y_2 CV score:  0.12737605980149372
# z_2 CV score:  0.08132268089846585
# x_3 CV score:  0.34863587687772374
# y_3 CV score:  0.20464932762347157
# z_3 CV score:  0.11013090456574288
# x_4 CV score:  0.5011708589925226
# y_4 CV score:  0.3083421540223798
# z_4 CV score:  0.13953710773846428
# x_5 CV score:  0.6779857974184866
# y_5 CV score:  0.4401948075123917
# z_5 CV score:  0.17015409281225097
# Total CV score:  0.20628914098909015

# %%
submission = pd.DataFrame(origin_test_ids).merge(preds, on='ID', how='left').drop(columns=['ID'])

output_path = OUTPUT_DIR / f'{exp_name}_{score:.4f}_submission.csv'
if output_path.exists():
    assert False, f'output file already exists. {output_path}'

submission.to_csv(output_path, index=False)
submission
# Out:
#            x_0       y_0       z_0        x_1       y_1       z_1        x_2  \
# 0     1.463991 -0.049669  0.002574   3.024819 -0.103862  0.002377   4.549850
# 1     0.944088  0.378684 -0.000358   1.768910  0.998596 -0.000870   2.410631
# 2     1.591044  0.013495  0.002318   3.318072  0.017580  0.002774   4.932899
# 3     0.822369  0.065218  0.000896   1.631042  0.211284 -0.000766   2.378557
# 4     0.825304  0.002796 -0.003021   1.414790 -0.011968 -0.007510   1.935306
# ...        ...       ...       ...        ...       ...       ...        ...
# 1722  6.544531  0.026155  0.013026  13.822683  0.104220  0.023885  21.092918
# 1723  6.980958  0.003513 -0.007516  14.877855 -0.006219 -0.042671  22.899712
# 1724  7.419286  0.001503  0.010735  15.684197 -0.011242  0.026853  23.913254
# 1725  6.538223  0.003831  0.006158  13.697659  0.009413  0.040417  20.787937
# 1726  5.803063 -0.257185 -0.000965  12.279611 -1.128776 -0.033392  18.781071
#
#            y_2       z_2        x_3       y_3       z_3        x_4       y_4  \
# 0    -0.115094 -0.000744   5.933706 -0.153886 -0.000478   7.405761 -0.063780
# 1     1.677103  0.000880   2.998322  2.490040 -0.001049   3.662633  3.327970
# 2     0.008146  0.001528   6.350708  0.041607  0.001049   7.819269 -0.006925
# 3     0.440283 -0.004066   2.998722  0.760857 -0.002977   3.582831  1.288276
# 4    -0.012879 -0.016259   2.300793 -0.005911 -0.022407   2.151273  0.003463
# ...        ...       ...        ...       ...       ...        ...       ...
# 1722  0.263541  0.026514  28.394687  0.508450  0.033328  35.687118  0.845035
# 1723  0.003107 -0.102094  31.006377 -0.017649 -0.183467  39.189364 -0.059877
# 1724 -0.015924  0.045822  32.052825 -0.034763  0.072825  40.114396 -0.088948
# 1725  0.034394  0.117537  27.832282  0.073148  0.232250  34.737154  0.111879
# 1726 -2.532442 -0.099566  25.323019 -4.411725 -0.178516  31.778557 -6.705263
#
#            z_4        x_5       y_5       z_5
# 0    -0.004364   8.763233 -0.061580 -0.007451
# 1     0.002954   4.266144  4.585862  0.004271
# 2    -0.004068   9.307925 -0.072504 -0.010551
# 3    -0.001650   4.188897  1.783152 -0.005913
# 4    -0.047799   1.657511  0.007600 -0.053745
# ...        ...        ...       ...       ...
# 1722  0.024753  43.249729  1.242502  0.019806
# 1723 -0.276454  47.422392 -0.063989 -0.382804
# 1724  0.097638  48.051192 -0.112241  0.117564
# 1725  0.373379  41.765041  0.195893  0.559160
# 1726 -0.275433  38.193890 -9.235973 -0.413894
#
# [1727 rows x 18 columns]
