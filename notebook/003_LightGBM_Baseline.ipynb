# %%
from pathlib import Path

import polars as pl
import pandas as pd
import numpy as np

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import OrdinalEncoder

import lightgbm as lgb

# %%
exp_name = '003_LightGBM_Baseline'

# %%
DATA_PATH = Path('/Users/gouyashuto/localrepository/atmacup18/input')
OUTPUT_DIR = Path('/Users/gouyashuto/localrepository/atmacup18/output')

# %%
train_df = pl.read_csv(DATA_PATH / 'train_features.csv')
test_df = pl.read_csv(DATA_PATH / 'test_features.csv')

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 30)
# (1727, 12)

# %%
CAT_COLS = ['gearShifter', 'scene']

TARGET_COLS = [
    'x_0', 'y_0', 'z_0',
    'x_1', 'y_1', 'z_1',
    'x_2', 'y_2', 'z_2',
    'x_3', 'y_3', 'z_3',
    'x_4', 'y_4', 'z_4',
    'x_5', 'y_5', 'z_5'
]

# %%
def get_agg_exprs(agg_cols) -> list[pl.Expr]:
    # 同一シーンから特徴量作成
    exprs = []
    exprs += [pl.col(agg_col).shift(-1).over("scene").alias(f"{agg_col}_shift-1") for agg_col in agg_cols] # 1ステップ前の時間の値
    exprs += [pl.col(agg_col).shift(1).over("scene").alias(f"{agg_col}_shift1") for agg_col in agg_cols] # 1ステップ後の時間の値
    exprs += [pl.col(agg_col).diff(-1).over("scene").alias(f"{agg_col}_diff-1") for agg_col in agg_cols] # 1ステップ前の時間の値との差分
    exprs += [pl.col(agg_col).diff(1).over("scene").alias(f"{agg_col}_diff1") for agg_col in agg_cols] # 1ステップ後の時間の値との差分
    exprs += [pl.col(agg_col).mean().over("scene").alias(f"{agg_col}_mean") for agg_col in agg_cols] # 同一シーンの平均値
    exprs += [pl.col(agg_col).std().over("scene").alias(f"{agg_col}_std") for agg_col in agg_cols] # 同一シーンの標準偏差
    exprs += [pl.col(agg_col).max().over("scene").alias(f"{agg_col}_max") for agg_col in agg_cols] # 同一シーンの最大値
    exprs += [pl.col(agg_col).min().over("scene").alias(f"{agg_col}_min") for agg_col in agg_cols] # 同一シーンの最小値
    return exprs

# %%
def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    agg_cols = ['vEgo', 'aEgo', 'steeringAngleDeg', 'steeringTorque', 'gas'] # 同一シーンから集計する値のカラム名
    df = (
        df
        .with_columns(
            scene = pl.col('ID').str.split('_').list[0],
            decisecond = pl.col('ID').str.split('_').list[1].cast(pl.Int32),
        )
        .sort(['scene', 'decisecond'])
        .with_columns(get_agg_exprs(agg_cols))
    )
    return df

# %%
def train(X: pd.DataFrame, y: pd.DataFrame, target: str):
    lgb_params = {
        'objective': 'regression',
        'metric': 'mae',
        'learning_rate': 0.01,
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'n_jobs': -1,
    }
    gkf = GroupKFold(n_splits=5)
    groups = X['scene']

    models = []
    oof = np.zeros(len(X))
    for fold, (train_idx, valid_idx) in enumerate(gkf.split(X, y[target], groups=groups)):
        print('=' * 10, f'fold: {fold} start' + '=' * 10)
        train_X = X.iloc[train_idx].drop(columns=['scene'])
        train_y = y[target].iloc[train_idx]
        valid_X = X.iloc[valid_idx].drop(columns=['scene'])
        valid_y = y[target].iloc[valid_idx]

        train_data = lgb.Dataset(train_X, train_y)
        valid_data = lgb.Dataset(valid_X, valid_y, reference=train_data)

        model = lgb.train(
            lgb_params,
            train_data,
            valid_sets=[valid_data],
            num_boost_round=10000,
            callbacks=[lgb.early_stopping(100)],
        )
        oof[valid_idx] = model.predict(valid_X)
        models.append(model)
    return models, oof

def predict(X: pd.DataFrame, models: list):
    preds = []
    for model in models:
        pred = model.predict(X.drop(columns=['scene']))
        preds.append(pred)
    return np.mean(preds, axis=0)

def evaluate(y_true: pd.DataFrame, y_pred: pd.DataFrame):
    return np.mean(np.abs(y_true - y_pred))

# %%
train_df = preprocess(train_df)

origin_test_ids = test_df['ID'].to_pandas()
test_df = preprocess(test_df)

print(train_df.shape)
print(test_df.shape)
# Out:
# (43371, 72)
# (1727, 54)

# %%
remove_columns = ['ID']
X = train_df.drop(remove_columns + TARGET_COLS).to_pandas()
y = train_df[TARGET_COLS].to_pandas()

test_X = test_df.drop(remove_columns).to_pandas()

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X[CAT_COLS] = oe.fit_transform(X[CAT_COLS])
test_X[CAT_COLS] = oe.transform(test_X[CAT_COLS])

print(X.shape)
print(test_X.shape)
# Out:
# (43371, 53)
# (1727, 53)

# %%
# %%time

models_dict = {}
oof = pd.DataFrame(np.zeros_like(train_df.to_pandas().loc[:, TARGET_COLS]), columns=TARGET_COLS)

preds = test_df.select(['ID']).to_pandas()
preds[TARGET_COLS] = 0.0

for target in TARGET_COLS:
    print('=' * 10, f'target: {target} start' + '=' * 10)
    partial_model, partial_oofs = train(X, y, target)
    models_dict[target] = partial_model
    oof.loc[:, target] = partial_oofs
    preds.loc[:, target] = predict(test_X, models_dict[target])
# Out:
# ========== target: x_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [980]	valid_0's l1: 0.0618087
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [831]	valid_0's l1: 0.0604472
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [879]	valid_0's l1: 0.0633197
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1252]	valid_0's l1: 0.0617252
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1251]	valid_0's l1: 0.0623725
# ========== target: y_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [500]	valid_0's l1: 0.0324583
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [489]	valid_0's l1: 0.0318535
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [702]	valid_0's l1: 0.0326572
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [594]	valid_0's l1: 0.0320545
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [560]	valid_0's l1: 0.0333533
# ========== target: z_0 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [121]	valid_0's l1: 0.0258875
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [251]	valid_0's l1: 0.0254061
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [235]	valid_0's l1: 0.0263651
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [280]	valid_0's l1: 0.0264042
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [147]	valid_0's l1: 0.0257218
# ========== target: x_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1062]	valid_0's l1: 0.13117
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1601]	valid_0's l1: 0.130861
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1324]	valid_0's l1: 0.133644
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1405]	valid_0's l1: 0.130951
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1429]	valid_0's l1: 0.133997
# ========== target: y_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1040]	valid_0's l1: 0.0740657
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1142]	valid_0's l1: 0.0723556
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1205]	valid_0's l1: 0.0749779
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1731]	valid_0's l1: 0.0730361
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2072]	valid_0's l1: 0.0748595
# ========== target: z_1 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [98]	valid_0's l1: 0.0540088
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [459]	valid_0's l1: 0.0526814
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [237]	valid_0's l1: 0.0546269
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [329]	valid_0's l1: 0.0552872
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	valid_0's l1: 0.0538502
# ========== target: x_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1399]	valid_0's l1: 0.222705
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1827]	valid_0's l1: 0.224706
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2006]	valid_0's l1: 0.225116
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2365]	valid_0's l1: 0.22304
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1811]	valid_0's l1: 0.227969
# ========== target: y_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3702]	valid_0's l1: 0.130759
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1517]	valid_0's l1: 0.13076
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2873]	valid_0's l1: 0.13302
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2394]	valid_0's l1: 0.129769
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2977]	valid_0's l1: 0.133226
# ========== target: z_2 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [148]	valid_0's l1: 0.0833025
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	valid_0's l1: 0.0808754
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [272]	valid_0's l1: 0.0839346
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [537]	valid_0's l1: 0.085713
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	valid_0's l1: 0.0832178
# ========== target: x_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2566]	valid_0's l1: 0.342429
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2776]	valid_0's l1: 0.350676
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2679]	valid_0's l1: 0.349843
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3009]	valid_0's l1: 0.345425
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2215]	valid_0's l1: 0.353065
# ========== target: y_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2286]	valid_0's l1: 0.213096
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2097]	valid_0's l1: 0.216629
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3265]	valid_0's l1: 0.218043
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3472]	valid_0's l1: 0.213865
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3080]	valid_0's l1: 0.218939
# ========== target: z_3 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [226]	valid_0's l1: 0.113773
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [498]	valid_0's l1: 0.110698
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [316]	valid_0's l1: 0.114411
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [433]	valid_0's l1: 0.116876
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [313]	valid_0's l1: 0.114547
# ========== target: x_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2148]	valid_0's l1: 0.492746
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3127]	valid_0's l1: 0.504187
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2976]	valid_0's l1: 0.505034
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3376]	valid_0's l1: 0.498661
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2834]	valid_0's l1: 0.505469
# ========== target: y_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3391]	valid_0's l1: 0.325486
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2427]	valid_0's l1: 0.335627
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3358]	valid_0's l1: 0.334923
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3473]	valid_0's l1: 0.327413
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3098]	valid_0's l1: 0.338455
# ========== target: z_4 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [318]	valid_0's l1: 0.145587
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [665]	valid_0's l1: 0.142183
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [387]	valid_0's l1: 0.146173
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [560]	valid_0's l1: 0.149184
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [465]	valid_0's l1: 0.146202
# ========== target: x_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2333]	valid_0's l1: 0.663383
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3426]	valid_0's l1: 0.680935
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2762]	valid_0's l1: 0.677691
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2852]	valid_0's l1: 0.675682
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4255]	valid_0's l1: 0.679718
# ========== target: y_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3641]	valid_0's l1: 0.468019
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2215]	valid_0's l1: 0.486229
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2943]	valid_0's l1: 0.486002
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2441]	valid_0's l1: 0.474302
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3609]	valid_0's l1: 0.490799
# ========== target: z_5 start==========
# ========== fold: 0 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [274]	valid_0's l1: 0.179167
# ========== fold: 1 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [546]	valid_0's l1: 0.175441
# ========== fold: 2 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l1: 0.179701
# ========== fold: 3 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [672]	valid_0's l1: 0.182533
# ========== fold: 4 start==========
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [409]	valid_0's l1: 0.179246
# CPU times: user 20min 38s, sys: 7min 53s, total: 28min 32s
# Wall time: 15min 24s

# %%
for target in TARGET_COLS:
    print(f'{target} CV score: ', evaluate(y[target], oof[target]))
score = evaluate(y, oof)
print('Total CV score: ', score)
# Out:
# x_0 CV score:  0.06193463658709383
# y_0 CV score:  0.03247537600638597
# z_0 CV score:  0.025956946282137176
# x_1 CV score:  0.1321245354288733
# y_1 CV score:  0.0738589619561076
# z_1 CV score:  0.054090912539904286
# x_2 CV score:  0.2247071252047433
# y_2 CV score:  0.13150689236672053
# z_2 CV score:  0.08340867136678622
# x_3 CV score:  0.34828743649531485
# y_3 CV score:  0.2161142213121716
# z_3 CV score:  0.11406105490110789
# x_4 CV score:  0.501219062964356
# y_4 CV score:  0.33238063614963015
# z_4 CV score:  0.14586561308569806
# x_5 CV score:  0.6754816385299667
# y_5 CV score:  0.4810698611399575
# z_5 CV score:  0.17921763564056822
# Total CV score:  0.2118756232198624

# %%
submission = pd.DataFrame(origin_test_ids).merge(preds, on='ID', how='left').drop(columns=['ID'])

output_path = OUTPUT_DIR / f'{exp_name}_{score:.4f}_submission.csv'
if output_path.exists():
    assert False, f'output file already exists. {output_path}'

submission.to_csv(output_path, index=False)
submission
# Out:
#            x_0       y_0       z_0        x_1       y_1       z_1        x_2  \
# 0     1.452000 -0.050903  0.002467   3.026742 -0.119529  0.004675   4.544577
# 1     0.943627  0.389217 -0.000403   1.740568  1.004104 -0.002847   2.405530
# 2     1.570422  0.016755  0.003852   3.247825  0.015135  0.007196   4.926408
# 3     0.834648  0.064781 -0.001332   1.646419  0.220114 -0.006990   2.422596
# 4     0.817229  0.004758 -0.001937   1.411591  0.002420 -0.004815   1.892143
# ...        ...       ...       ...        ...       ...       ...        ...
# 1722  6.536803  0.009177  0.017746  13.799471  0.048440  0.039545  21.005841
# 1723  7.000525  0.000949  0.004384  14.893628 -0.009496  0.008282  22.941824
# 1724  7.416801 -0.001224  0.007200  15.665913 -0.020713  0.011577  23.899243
# 1725  6.524221 -0.000424 -0.002032  13.669658 -0.009155 -0.004767  20.764941
# 1726  5.814603 -0.247394  0.008775  12.324518 -1.045247  0.012275  18.922288
#
#            y_2       z_2        x_3       y_3       z_3        x_4       y_4  \
# 0    -0.190624  0.002538   5.831274 -0.207156  0.004310   7.260501 -0.123238
# 1     1.776283 -0.007880   2.792622  2.618284 -0.010512   3.564011  3.554118
# 2     0.044127  0.011402   6.314183  0.053395  0.012119   7.774819  0.119132
# 3     0.541451 -0.012222   2.967670  0.854678 -0.019287   3.636090  1.512227
# 4    -0.000868 -0.017368   2.266762 -0.003869 -0.038374   2.182538 -0.002873
# ...        ...       ...        ...       ...       ...        ...       ...
# 1722  0.130692  0.065820  28.265819  0.220888  0.073843  35.563229  0.328178
# 1723 -0.028283  0.012853  31.099251 -0.064447  0.023554  39.282124 -0.098533
# 1724 -0.055145  0.022928  32.062863 -0.120521  0.047047  40.125042 -0.194544
# 1725 -0.009719 -0.009016  27.814852 -0.011040 -0.012842  34.837266 -0.019661
# 1726 -2.348087  0.016325  25.540232 -4.123228  0.005142  32.013455 -6.189844
#
#            z_4        x_5       y_5       z_5
# 0    -0.005506   8.597789 -0.003056 -0.003567
# 1    -0.008003   4.331309  4.561916  0.000610
# 2     0.015144   8.932256  0.197387  0.021751
# 3    -0.021030   4.295287  2.240007 -0.016445
# 4    -0.051923   1.739183 -0.022205 -0.069277
# ...        ...        ...       ...       ...
# 1722  0.080398  42.982216  0.452140  0.070313
# 1723  0.030263  47.521092 -0.133894  0.037108
# 1724  0.077168  48.065559 -0.265605  0.090351
# 1725 -0.015308  41.825263  0.012250 -0.015824
# 1726 -0.046527  38.548946 -8.547166 -0.117428
#
# [1727 rows x 18 columns]
